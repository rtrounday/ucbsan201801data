# %%
#Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.linear_model import LinearRegression
import fix_yahoo_finance as yf

# %%
Df = yf.download('GLD', '2008-01-01', '2018-07-08')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
Df=Df[['Close']]

# %%
Df
# Out:
#                  Close
# Date
# 2008-01-02   84.860001
# 2008-01-03   85.570000
# 2008-01-04   85.129997
# 2008-01-07   84.769997
# 2008-01-08   86.779999
# 2008-01-09   86.550003
# 2008-01-10   88.250000
# 2008-01-11   88.580002
# 2008-01-14   89.540001
# 2008-01-15   87.989998
# 2008-01-16   86.699997
# 2008-01-17   86.500000
# 2008-01-18   87.419998
# 2008-01-22   88.169998
# 2008-01-23   87.889999
# 2008-01-24   90.080002
# 2008-01-25   90.300003
# 2008-01-28   91.750000
# 2008-01-29   91.150002
# 2008-01-30   92.059998
# 2008-01-31   91.400002
# 2008-02-01   89.349998
# 2008-02-04   89.099998
# 2008-02-05   87.680000
# 2008-02-06   88.949997
# 2008-02-07   89.849998
# 2008-02-08   91.000000
# 2008-02-11   91.330002
# 2008-02-12   89.330002
# 2008-02-13   89.440002
# ...                ...
# 2018-05-24  123.589996
# 2018-05-25  123.209999
# 2018-05-29  123.190002
# 2018-05-30  123.370003
# 2018-05-31  123.099998
# 2018-06-01  122.489998
# 2018-06-04  122.370003
# 2018-06-05  122.849998
# 2018-06-06  122.919998
# 2018-06-07  122.860001
# 2018-06-08  123.010002
# 2018-06-11  123.230003
# 2018-06-12  122.820000
# 2018-06-13  123.190002
# 2018-06-14  123.379997
# 2018-06-15  121.339996
# 2018-06-18  121.110001
# 2018-06-19  120.800003
# 2018-06-20  120.260002
# 2018-06-21  120.050003
# 2018-06-22  120.339996
# 2018-06-25  119.889999
# 2018-06-26  119.260002
# 2018-06-27  118.580002
# 2018-06-28  118.220001
# 2018-06-29  118.650002
# 2018-07-02  117.459999
# 2018-07-03  118.650002
# 2018-07-05  119.050003
# 2018-07-06  118.860001
#
# [2647 rows x 1 columns]

# %%
Df= Df.dropna()

# %%
Df.Close.plot(figsize=(15,10))

# %%
plt.title('GLD')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')

# %%
plt.show()

# %%
Df['SMA_3'] = Df['Close'].shift(1).rolling(window=3).mean()
Df['SMA_9'] = Df['Close'].shift(1).rolling(window=9).mean()
Df= Df.dropna()
X = Df[['SMA_3','SMA_9']]
X.head()
# Out:
#                 SMA_3      SMA_9
# Date
# 2008-01-15  88.790001  86.670000
# 2008-01-16  88.703334  87.017777
# 2008-01-17  88.076665  87.143333
# 2008-01-18  87.063332  87.295555
# 2008-01-22  86.873332  87.590000

# %%
y = Df['Close']
y.head()
# Out:
# Date
# 2008-01-15    87.989998
# 2008-01-16    86.699997
# 2008-01-17    86.500000
# 2008-01-18    87.419998
# 2008-01-22    88.169998
# Name: Close, dtype: float64

# %%
t=.8
t= int(t*len(Df))
X_train = X[:t]
y_train = y[:t]
X_test = X[t:]
y_test = y[t:]

# %%
## Create Linear regression Model
linear = LinearRegression().fit(X_train,y_train)
print ("Price =", round(linear.coef_[0],2), \
"* 3SMA", round(linear.coef_[1],2), \
"* 9SMA +", round(linear.intercept_,2))
# Out:
# Price = 1.2 * 3SMA -0.2 * 9SMA + 0.41

# %%
p_price = linear.predict(X_test)
p_price = pd.DataFrame(p_price,index=y_test.index,columns = ['price'])
p_price.plot(figsize=(15,10))
y_test.plot()
plt.legend(['predicted_price','actual_price'])
plt.ylabel("Price")
plt.show()

# %%
r2 = linear.score(X[t:],y[t:])*100
float("{0:.2f}".format(r2))
# Out:
# 94.83
